# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(15.096070423159773, 175.67250357370898), (-47.33772627073353, -11.71894047846618), (79.62100592328665, 55.49487641877931), (34.99836164548422, 113.08438128921233), (-77.52312855971539, 86.74008805314031), (61.28029397592479, -50.243071251516994), (15.570642017298624, -76.16391212168962), (45.811235255956205, -162.16061885864406), (-56.53085279756388, -93.7832989318322), (-16.765460303608222, -151.67639245065195), (-82.5478651122052, 65.56754555698029), (-60.56881531126971, -43.99600122686036), (-14.708025950576555, 119.67294643617163), (-70.09377061834255, 152.19763311498974), (69.13109182412734, -39.67206134924811), (-82.69667597986559, 40.767468036377096), (-25.823460075344684, 83.41522189877304), (-37.23816365260128, 84.6936145977466), (-67.9104455000274, -13.268139925472639), (22.008704063382666, 168.64593882804456), (5.217822657321065, -168.94073732430903), (-35.54960193064844, 127.91702225258246), (-40.84239640925326, -105.61469764292752), (-30.86255144506162, 79.54067828765818), (33.587573843850606, 65.69473947527533), (-58.91473535470256, -158.0702196913404), (46.83008466945665, -107.56208055512927), (-44.3602821904192, 165.50938848285517), (-8.224452359386675, 120.37630803627297), (-66.73021851332658, -84.35347163800515), (-22.41105896940769, -126.32547570959497), (-11.09847510000624, -73.19699738503347), (34.57952719743592, -20.783341518093067), (47.71600171039697, -3.4875125719343885), (84.69641499688305, -16.40047868282602), (-87.00552894165497, -89.3684227817848), (68.85067086263345, 172.91733772805435), (-48.72528739106091, -127.50246178613453), (8.62270542047888, -61.2355791209914), (66.63038184669665, 153.5192831960702), (25.513959324868594, 177.44227086446432), (6.9771584584023, 78.81537387359049), (-57.66712038288599, -171.41330516231915), (52.59052733207474, -124.70371666563068), (-82.78830546246587, -91.53578052059598), (64.87722840800433, -38.24000652229711), (-24.062927742878017, -176.25822152697518), (-35.47011689778393, -101.6147812159506), (29.8098617437486, -151.0911148939678), (55.33921818601294, -84.74234631853506), (34.63378364811612, -145.04361591363886), (-56.22968691787243, 83.7020182281467), (53.31213451033224, 53.56422030470759), (-8.568764996635494, 141.99057590257496), (80.16435450879493, -104.1774291793479), (-74.25921354733777, 55.13725369619323), (64.64041857249296, 159.72943931106948), (-29.23621530133942, 74.57894723373681), (-39.00589720394801, 135.66203142250328), (-51.37026565807676, -19.275761461871014), (-54.041098810218465, -179.71864823954408), (69.41609517158409, -108.96694305024772), (33.0825894794194, -105.75951018233602), (62.33614768929479, 62.48352965315564), (12.090765886530747, -82.3006924341959), (-21.313224875457067, 50.76808212837767), (-33.685642969426155, -158.5108579896798), (35.01963007768647, -135.58429384250223), (16.328624599041817, -129.4047969313655), (-50.65336577310297, -72.1823304938326), (44.185960965791026, -6.971879382649206), (-43.91192445667235, 151.52223739176554), (-61.00251061070613, 25.879694899004363), (-12.821518713767546, -87.9807085437936), (-70.17359233721317, 143.49480258038665), (-40.19584174664047, -29.142893476581264), (-49.85916865836841, -113.59947739278184), (-34.012258747310355, -139.3483896183209), (27.425617813648415, 110.22996923828958), (-17.089208536954004, 48.278807838022715), (6.799573070904188, -80.5351159549352), (-2.6624081991340915, -133.51235902204292), (42.23165822888086, -142.52893253719208), (-40.25655677840835, -69.06773838084082), (-88.60567192537687, 129.42450799382823), (-31.026665846162146, 129.29759900015517), (16.970617911301744, 62.32889569687265), (87.33492349759675, -61.65214472958945), (56.397720417310296, -15.290429620825165), (-81.87648288531767, 95.69058028493345), (-30.57331010887443, 40.366372208907364), (-1.2617016364019236, -143.62753978893295), (11.942575502923233, -79.45875863310442), (21.890903430749404, 18.727635766563537), (75.01640305307976, -10.760409484174943), (-82.96592312600008, -3.37834710 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | xiaoyi
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | morant bay
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | tevaitoa
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | broome
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | deh rawud
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | billings
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | ruteng
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | pangoa
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | ploemeur
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | komsomolskiy
# Processing Record 34 of Set 1 | tucupita
# Processing Record 35 of Set 1 | srednekolymsk
# Processing Record 36 of Set 1 | colombo
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | vanderhoof
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | kahului
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | abdulino
# Processing Record 43 of Set 1 | morehead
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | evensk
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | ruidoso
# Processing Record 50 of Set 1 | agirish
# Processing Record 1 of Set 2 | corn island
# Processing Record 2 of Set 2 | nosy varika
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | cervo
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | chicama
# Processing Record 9 of Set 2 | anjiang
# Processing Record 10 of Set 2 | andilamena
# Processing Record 11 of Set 2 | la palma
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | neuquen
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | sur
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | westport
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | san andres
# Processing Record 23 of Set 2 | faya
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | kuching
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | mpika
# Processing Record 29 of Set 2 | sompeta
# Processing Record 30 of Set 2 | rantepao
# Processing Record 31 of Set 2 | wanaka
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | hay river
# Processing Record 34 of Set 2 | mehamn
# Processing Record 35 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 2 | moses lake
# Processing Record 37 of Set 2 | north bend
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | port moresby
# Processing Record 40 of Set 2 | jacobabad
# Processing Record 41 of Set 2 | homnabad
# Processing Record 42 of Set 2 | copiapo
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | havoysund
# Processing Record 45 of Set 2 | khorramabad
# Processing Record 46 of Set 2 | amga
# Processing Record 47 of Set 2 | west wendover
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | hambantota
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | mantua
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | miri
# Processing Record 6 of Set 3 | inhambane
# Processing Record 7 of Set 3 | kendari
# Processing Record 8 of Set 3 | agadir
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | chadan
# Processing Record 14 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 3 | roald
# Processing Record 18 of Set 3 | zhangjiakou
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | dingle
# Processing Record 22 of Set 3 | niono
# Processing Record 23 of Set 3 | riberalta
# Processing Record 24 of Set 3 | kutum
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | oktyabrskiy
# Processing Record 27 of Set 3 | gwanda
# Processing Record 28 of Set 3 | zyryanka
# Processing Record 29 of Set 3 | eureka
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | akdepe
# Processing Record 32 of Set 3 | cabedelo
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | stromness
# Processing Record 35 of Set 3 | lompoc
# Processing Record 36 of Set 3 | shakiso
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | kloulklubed
# Processing Record 39 of Set 3 | wagga wagga
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | campbell river
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | kapoeta
# Processing Record 44 of Set 3 | goderich
# Processing Record 45 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 3 | pimentel
# Processing Record 47 of Set 3 | nemuro
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | hasaki
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | koboldo
# City not found. Skipping...
# Processing Record 6 of Set 4 | marawi
# Processing Record 7 of Set 4 | casper
# Processing Record 8 of Set 4 | waipawa
# Processing Record 9 of Set 4 | ejido
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | sananduva
# Processing Record 12 of Set 4 | itarema
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | ostrovnoy
# Processing Record 15 of Set 4 | lhuntshi
# City not found. Skipping...
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | praya
# Processing Record 18 of Set 4 | barrow
# Processing Record 19 of Set 4 | mazatlan
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | saint-augustin
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | accra
# Processing Record 25 of Set 4 | honiara
# Processing Record 26 of Set 4 | tuktoyaktuk
# Processing Record 27 of Set 4 | andenes
# Processing Record 28 of Set 4 | tucuma
# Processing Record 29 of Set 4 | emba
# Processing Record 30 of Set 4 | puerto ayora
# Processing Record 31 of Set 4 | bahia blanca
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | sembe
# Processing Record 34 of Set 4 | taltal
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | tricase
# Processing Record 37 of Set 4 | tuatapere
# Processing Record 38 of Set 4 | beyla
# Processing Record 39 of Set 4 | inirida
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | saint-joseph
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | khilok
# Processing Record 44 of Set 4 | tublay
# Processing Record 45 of Set 4 | bairiki
# Processing Record 46 of Set 4 | bara
# Processing Record 47 of Set 4 | pallisa
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | rio gallegos
# Processing Record 50 of Set 4 | clarence town
# Processing Record 1 of Set 5 | adolfo ruiz cortines
# Processing Record 2 of Set 5 | lata
# Processing Record 3 of Set 5 | sovetskiy
# Processing Record 4 of Set 5 | zabaykalsk
# Processing Record 5 of Set 5 | ayna
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | aksu
# Processing Record 8 of Set 5 | brufut
# Processing Record 9 of Set 5 | khed brahma
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | griffith
# Processing Record 13 of Set 5 | qaqortoq
# Processing Record 14 of Set 5 | rognan
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | kurchatov
# Processing Record 17 of Set 5 | castro
# Processing Record 18 of Set 5 | puerto del rosario
# Processing Record 19 of Set 5 | cartagena del chaira
# Processing Record 20 of Set 5 | letka
# Processing Record 21 of Set 5 | santa isabel do rio negro
# Processing Record 22 of Set 5 | san ramon de la nueva oran
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | gotsu
# Processing Record 25 of Set 5 | faanui
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | san rafael
# Processing Record 28 of Set 5 | requena
# Processing Record 29 of Set 5 | guozhen
# Processing Record 30 of Set 5 | pervomayskoye
# Processing Record 31 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | kieta
# Processing Record 34 of Set 5 | moree
# Processing Record 35 of Set 5 | novouzensk
# Processing Record 36 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 5 | tayginka
# Processing Record 38 of Set 5 | riyadh
# Processing Record 39 of Set 5 | kuusamo
# Processing Record 40 of Set 5 | panama city
# Processing Record 41 of Set 5 | hvolsvollur
# Processing Record 42 of Set 5 | lazaro cardenas
# Processing Record 43 of Set 5 | luwuk
# Processing Record 44 of Set 5 | ginir
# Processing Record 45 of Set 5 | cavalcante
# Processing Record 46 of Set 5 | seoul
# Processing Record 47 of Set 5 | qasigiannguit
# Processing Record 48 of Set 5 | miajadas
# Processing Record 49 of Set 5 | hobyo
# Processing Record 50 of Set 5 | tiznit
# Processing Record 1 of Set 6 | henties bay
# Processing Record 2 of Set 6 | isla vista
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | babu
# Processing Record 5 of Set 6 | alihe
# Processing Record 6 of Set 6 | palkonda
# Processing Record 7 of Set 6 | nioro
# Processing Record 8 of Set 6 | tahta
# Processing Record 9 of Set 6 | cleveland
# Processing Record 10 of Set 6 | caibarien
# Processing Record 11 of Set 6 | upernavik
# Processing Record 12 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 6 | graham
# Processing Record 14 of Set 6 | hilo
# Processing Record 15 of Set 6 | mar del plata
# Processing Record 16 of Set 6 | jinchang
# Processing Record 17 of Set 6 | takoradi
# Processing Record 18 of Set 6 | kabo
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | morondava
# Processing Record 22 of Set 6 | orguz
# Processing Record 23 of Set 6 | aleksandrovskiy zavod
# Processing Record 24 of Set 6 | awbari
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | cap malheureux
# Processing Record 27 of Set 6 | marrakesh
# Processing Record 28 of Set 6 | parabel
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | puerto leguizamo
# Processing Record 31 of Set 6 | cairns
# Processing Record 32 of Set 6 | anadyr
# Processing Record 33 of Set 6 | gavle
# Processing Record 34 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 6 | falun
# Processing Record 36 of Set 6 | tessalit
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | argentan
# Processing Record 39 of Set 6 | olga
# Processing Record 40 of Set 6 | shimoda
# Processing Record 41 of Set 6 | krasnyy oktyabr
# Processing Record 42 of Set 6 | san luis
# Processing Record 43 of Set 6 | fairbanks
# Processing Record 44 of Set 6 | rudnichnyy
# Processing Record 45 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 6 | massaguet
# Processing Record 47 of Set 6 | luangwa
# Processing Record 48 of Set 6 | dhamnod
# Processing Record 49 of Set 6 | majene
# Processing Record 50 of Set 6 | barcelos
# Processing Record 1 of Set 7 | kamskoye ustye
# Processing Record 2 of Set 7 | uvalde
# Processing Record 3 of Set 7 | wenling
# Processing Record 4 of Set 7 | ambunti
# Processing Record 5 of Set 7 | musoma
# Processing Record 6 of Set 7 | muisne
# Processing Record 7 of Set 7 | saint-francois
# Processing Record 8 of Set 7 | valparaiso
# Processing Record 9 of Set 7 | masyaf
# Processing Record 10 of Set 7 | tiksi
# Processing Record 11 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 7 | badami
# Processing Record 13 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 7 | luebo
# Processing Record 15 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 16 of Set 7 | sambava
# Processing Record 17 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 18 of Set 7 | marigot
# Processing Record 19 of Set 7 | lima
# Processing Record 20 of Set 7 | tanabe
# Processing Record 21 of Set 7 | chipiona
# Processing Record 22 of Set 7 | tevriz
# Processing Record 23 of Set 7 | enterprise
# Processing Record 24 of Set 7 | tazovskiy
# Processing Record 25 of Set 7 | zhaotong
# Processing Record 26 of Set 7 | camopi
# Processing Record 27 of Set 7 | port elizabeth
# Processing Record 28 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | asau
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | whyalla
# Processing Record 33 of Set 7 | lufilufi
# Processing Record 34 of Set 7 | borzya
# Processing Record 35 of Set 7 | arrifes
# Processing Record 36 of Set 7 | haines junction
# Processing Record 37 of Set 7 | priargunsk
# Processing Record 38 of Set 7 | mahebourg
# Processing Record 39 of Set 7 | vardo
# Processing Record 40 of Set 7 | iquitos
# Processing Record 41 of Set 7 | lavrentiya
# Processing Record 42 of Set 7 | yangambi
# Processing Record 43 of Set 7 | nizhniy tsasuchey
# Processing Record 44 of Set 7 | huron
# Processing Record 45 of Set 7 | champerico
# Processing Record 46 of Set 7 | portree
# Processing Record 47 of Set 7 | birin
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | tinaquillo
# Processing Record 50 of Set 7 | ambon
# Processing Record 1 of Set 8 | san policarpo
# Processing Record 2 of Set 8 | tautira
# Processing Record 3 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 8 | raymond
# Processing Record 5 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | puro
# Processing Record 8 of Set 8 | saskylakh
# Processing Record 9 of Set 8 | mahwa
# Processing Record 10 of Set 8 | sao felix do xingu
# Processing Record 11 of Set 8 | lingao
# Processing Record 12 of Set 8 | palombara sabina
# Processing Record 13 of Set 8 | zhumadian
# Processing Record 14 of Set 8 | jacareacanga
# Processing Record 15 of Set 8 | porto novo
# Processing Record 16 of Set 8 | brae
# Processing Record 17 of Set 8 | kodiak
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | the valley
# Processing Record 20 of Set 8 | saint-philippe
# Processing Record 21 of Set 8 | vanimo
# Processing Record 22 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 23 of Set 8 | kauhajoki
# Processing Record 24 of Set 8 | bartlesville
# Processing Record 25 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 8 | atasu
# Processing Record 27 of Set 8 | xining
# Processing Record 28 of Set 8 | hun
# Processing Record 29 of Set 8 | nhamunda
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | prince rupert
# Processing Record 32 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 33 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 8 | longyearbyen
# Processing Record 35 of Set 8 | pavlodar
# Processing Record 36 of Set 8 | ambilobe
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | rio grande
# Processing Record 39 of Set 8 | yumen
# Processing Record 40 of Set 8 | kavieng
# Processing Record 41 of Set 8 | sobolevo
# Processing Record 42 of Set 8 | hamilton
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | abengourou
# Processing Record 45 of Set 8 | ketchikan
# Processing Record 46 of Set 8 | kununurra
# Processing Record 47 of Set 8 | avera
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | wilmington
# Processing Record 1 of Set 9 | mujiayingzi
# Processing Record 2 of Set 9 | biak
# Processing Record 3 of Set 9 | berlevag
# Processing Record 4 of Set 9 | potosi
# Processing Record 5 of Set 9 | sao pedro da aldeia
# Processing Record 6 of Set 9 | malanville
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | cidreira
# Processing Record 9 of Set 9 | qujing
# Processing Record 10 of Set 9 | lofthus
# Processing Record 11 of Set 9 | codrington
# Processing Record 12 of Set 9 | kaitangata
# Processing Record 13 of Set 9 | bartoszyce
# Processing Record 14 of Set 9 | eyemouth
# Processing Record 15 of Set 9 | loikaw
# Processing Record 16 of Set 9 | matara
# Processing Record 17 of Set 9 | shimoga
# Processing Record 18 of Set 9 | whithorn
# Processing Record 19 of Set 9 | talnakh
# Processing Record 20 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 9 | la ronge
# Processing Record 22 of Set 9 | yankton
# Processing Record 23 of Set 9 | verkhoturye
# Processing Record 24 of Set 9 | rio branco do sul
# Processing Record 25 of Set 9 | kajaani
# Processing Record 26 of Set 9 | valdivia
# Processing Record 27 of Set 9 | tambopata
# Processing Record 28 of Set 9 | hualmay
# Processing Record 29 of Set 9 | xiongzhou
# Processing Record 30 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 32 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 9 | mafeteng
# Processing Record 34 of Set 9 | crateus
# Processing Record 35 of Set 9 | gondar
# Processing Record 36 of Set 9 | samfya
# Processing Record 37 of Set 9 | taoudenni
# Processing Record 38 of Set 9 | itigi
# Processing Record 39 of Set 9 | soyo
# Processing Record 40 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 9 | liberty
# Processing Record 42 of Set 9 | maba
# Processing Record 43 of Set 9 | lakhnadon
# Processing Record 44 of Set 9 | mwadui
# Processing Record 45 of Set 9 | chivilcoy
# Processing Record 46 of Set 9 | kuandian
# Processing Record 47 of Set 9 | price
# Processing Record 48 of Set 9 | logatec
# Processing Record 49 of Set 9 | plyussa
# Processing Record 50 of Set 9 | chaa-khol
# City not found. Skipping...
# Processing Record 1 of Set 10 | pirapora
# Processing Record 2 of Set 10 | goba
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | nurota
# Processing Record 5 of Set 10 | novska
# Processing Record 6 of Set 10 | port-gentil
# Processing Record 7 of Set 10 | nabagram
# Processing Record 8 of Set 10 | pochutla
# Processing Record 9 of Set 10 | alice springs
# Processing Record 10 of Set 10 | shimanovsk
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | fryanovo
# Processing Record 13 of Set 10 | bonthe
# Processing Record 14 of Set 10 | salalah
# Processing Record 15 of Set 10 | pafos
# Processing Record 16 of Set 10 | huarmey
# Processing Record 17 of Set 10 | sainte-martine
# Processing Record 18 of Set 10 | palmer
# Processing Record 19 of Set 10 | waddan
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | labelle
# Processing Record 22 of Set 10 | santa maria
# Processing Record 23 of Set 10 | wonthaggi
# Processing Record 24 of Set 10 | mga
# Processing Record 25 of Set 10 | buraydah
# Processing Record 26 of Set 10 | adrar
# Processing Record 27 of Set 10 | belyy yar
# Processing Record 28 of Set 10 | ornskoldsvik
# Processing Record 29 of Set 10 | plettenberg bay
# Processing Record 30 of Set 10 | bom jardim
# Processing Record 31 of Set 10 | nizhniy odes
# Processing Record 32 of Set 10 | hutchinson
# Processing Record 33 of Set 10 | anori
# Processing Record 34 of Set 10 | kathmandu
# Processing Record 35 of Set 10 | viedma
# Processing Record 36 of Set 10 | pontianak
# Processing Record 37 of Set 10 | poum
# Processing Record 38 of Set 10 | balabac
# Processing Record 39 of Set 10 | port-cartier
# Processing Record 40 of Set 10 | beyneu
# Processing Record 41 of Set 10 | port hedland
# Processing Record 42 of Set 10 | kaeo
# Processing Record 43 of Set 10 | sibu
# Processing Record 44 of Set 10 | labuhan
# Processing Record 45 of Set 10 | salmas
# Processing Record 46 of Set 10 | mao
# Processing Record 47 of Set 10 | svetlogorsk
# Processing Record 48 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 10 | maniitsoq
# Processing Record 50 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 11 | jiehu
# Processing Record 2 of Set 11 | sai buri
# Processing Record 3 of Set 11 | biharamulo
# Processing Record 4 of Set 11 | dayong
# Processing Record 5 of Set 11 | nikolayevsk-na-amure
# Processing Record 6 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 11 | alofi
# Processing Record 8 of Set 11 | arefu
# Processing Record 9 of Set 11 | zhmerynka
# Processing Record 10 of Set 11 | korla
# Processing Record 11 of Set 11 | atbasar
# Processing Record 12 of Set 11 | hovd
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | novyy urengoy
# Processing Record 15 of Set 11 | umm kaddadah
# Processing Record 16 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 11 | aquin
# Processing Record 18 of Set 11 | nova borova
# Processing Record 19 of Set 11 | meadow lake
# Processing Record 20 of Set 11 | walvis bay
# Processing Record 21 of Set 11 | rudbar
# Processing Record 22 of Set 11 | nelson bay
# Processing Record 23 of Set 11 | richards bay
# Processing Record 24 of Set 11 | ahipara
# Processing Record 25 of Set 11 | george town
# Processing Record 26 of Set 11 | keffi
# Processing Record 27 of Set 11 | tual
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | matamoros
# Processing Record 30 of Set 11 | mundo novo
# Processing Record 31 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 11 | guacimo
# Processing Record 33 of Set 11 | menongue
# Processing Record 34 of Set 11 | shizunai
# Processing Record 35 of Set 11 | dunedin
# Processing Record 36 of Set 11 | mackay
# Processing Record 37 of Set 11 | saint-louis
# Processing Record 38 of Set 11 | talara
# Processing Record 39 of Set 11 | waitati
# Processing Record 40 of Set 11 | dauphin
# Processing Record 41 of Set 11 | touros
# Processing Record 42 of Set 11 | bongandanga
# Processing Record 43 of Set 11 | catamarca
# Processing Record 44 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 11 | verdalsora
# City not found. Skipping...
# Processing Record 46 of Set 11 | kitimat
# Processing Record 47 of Set 11 | praia da vitoria
# Processing Record 48 of Set 11 | pacific grove
# Processing Record 49 of Set 11 | isawa
# Processing Record 50 of Set 11 | saint anthony
# Processing Record 1 of Set 12 | dakar
# Processing Record 2 of Set 12 | talen
# Processing Record 3 of Set 12 | hami
# Processing Record 4 of Set 12 | tura
# Processing Record 5 of Set 12 | erenhot
# Processing Record 6 of Set 12 | aripuana
# Processing Record 7 of Set 12 | dudinka
# Processing Record 8 of Set 12 | ngunguru
# Processing Record 9 of Set 12 | jeremie
# Processing Record 10 of Set 12 | francisco beltrao
# Processing Record 11 of Set 12 | saint george
# Processing Record 12 of Set 12 | arlit
# Processing Record 13 of Set 12 | pisco
# Processing Record 14 of Set 12 | xingyi
# Processing Record 15 of Set 12 | aykhal
# Processing Record 16 of Set 12 | ladnun
# Processing Record 17 of Set 12 | san quintin
# Processing Record 18 of Set 12 | wucheng
# Processing Record 19 of Set 12 | andros town
# Processing Record 20 of Set 12 | boke
# Processing Record 21 of Set 12 | wewak
# Processing Record 22 of Set 12 | luanda
# Processing Record 23 of Set 12 | canon city
# Processing Record 24 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 12 | berea
# Processing Record 26 of Set 12 | zheleznodorozhnyy
# Processing Record 27 of Set 12 | itacare
# Processing Record 28 of Set 12 | jonesboro
# Processing Record 29 of Set 12 | beitbridge
# Processing Record 30 of Set 12 | kostino
# Processing Record 31 of Set 12 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 32 of Set 12 | durban
# Processing Record 33 of Set 12 | ucluelet
# Processing Record 34 of Set 12 | clyde river
# Processing Record 35 of Set 12 | christchurch
# Processing Record 36 of Set 12 | prainha
# Processing Record 37 of Set 12 | kerouane
# Processing Record 38 of Set 12 | vila velha
# Processing Record 39 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 12 | kawalu
# Processing Record 41 of Set 12 | azul
# Processing Record 42 of Set 12 | sibolga
# Processing Record 43 of Set 12 | bonavista
# Processing Record 44 of Set 12 | lao cai
# Processing Record 45 of Set 12 | alexandria
# Processing Record 46 of Set 12 | sistranda
# Processing Record 47 of Set 12 | altamira
# Processing Record 48 of Set 12 | altagracia de orituco
# Processing Record 49 of Set 12 | vilyuysk
# Processing Record 50 of Set 12 | lodja
# Processing Record 1 of Set 13 | general roca
# Processing Record 2 of Set 13 | nacala
# Processing Record 3 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 13 | vila franca do campo
# Processing Record 5 of Set 13 | angren
# Processing Record 6 of Set 13 | krasnoselkup
# Processing Record 7 of Set 13 | qui nhon
# Processing Record 8 of Set 13 | ola
# Processing Record 9 of Set 13 | laguna
# Processing Record 10 of Set 13 | vila
# Processing Record 11 of Set 13 | dwarka
# Processing Record 12 of Set 13 | tortoli
# Processing Record 13 of Set 13 | tuyen quang
# Processing Record 14 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 15 of Set 13 | chongwe
# Processing Record 16 of Set 13 | tambura
# Processing Record 17 of Set 13 | mestia
# Processing Record 18 of Set 13 | teknaf
# Processing Record 19 of Set 13 | mala danylivka
# Processing Record 20 of Set 13 | solnechnyy
# Processing Record 21 of Set 13 | tiarei
# Processing Record 22 of Set 13 | manggar
# Processing Record 23 of Set 13 | liverpool
# Processing Record 24 of Set 13 | diffa
# Processing Record 25 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 13 | quatre cocos
# Processing Record 27 of Set 13 | fereydun kenar
# Processing Record 28 of Set 13 | caravelas
# Processing Record 29 of Set 13 | chama
# Processing Record 30 of Set 13 | loandjili
# Processing Record 31 of Set 13 | suntar
# Processing Record 32 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 33 of Set 13 | petatlan
# Processing Record 34 of Set 13 | miramar
# Processing Record 35 of Set 13 | olinda
# Processing Record 36 of Set 13 | charters towers
# Processing Record 37 of Set 13 | bandarbeyla
# Processing Record 38 of Set 13 | noyabrsk
# Processing Record 39 of Set 13 | asfi
# Processing Record 40 of Set 13 | ixtapa
# Processing Record 41 of Set 13 | onega
# Processing Record 42 of Set 13 | vysokogornyy
# Processing Record 43 of Set 13 | palauig
# Processing Record 44 of Set 13 | zacualpan
# Processing Record 45 of Set 13 | aracataca
# Processing Record 46 of Set 13 | basco
# Processing Record 47 of Set 13 | vawkavysk
# Processing Record 48 of Set 13 | shelburne
# Processing Record 49 of Set 13 | pangnirtung
# Processing Record 50 of Set 13 | carlos chagas
# Processing Record 1 of Set 14 | pinheiro machado
# Processing Record 2 of Set 14 | makinsk
# Processing Record 3 of Set 14 | yahotyn
# Processing Record 4 of Set 14 | sorong
# Processing Record 5 of Set 14 | gibsons
# Processing Record 6 of Set 14 | nouadhibou
# Processing Record 7 of Set 14 | chimore
# Processing Record 8 of Set 14 | tuttlingen
# Processing Record 9 of Set 14 | nsanje
# Processing Record 10 of Set 14 | esna
# Processing Record 11 of Set 14 | dondo
# Processing Record 12 of Set 14 | adzope
# Processing Record 13 of Set 14 | cockburn town
# Processing Record 14 of Set 14 | maracaju
# Processing Record 15 of Set 14 | fukue
# Processing Record 16 of Set 14 | phan thong
# Processing Record 17 of Set 14 | skelleftea
# Processing Record 18 of Set 14 | dali
# Processing Record 19 of Set 14 | broken hill
# Processing Record 20 of Set 14 | nawa
# Processing Record 21 of Set 14 | san carlos
# Processing Record 22 of Set 14 | yaan
# Processing Record 23 of Set 14 | estacion coahuila
# Processing Record 24 of Set 14 | atka
# City not found. Skipping...
# Processing Record 25 of Set 14 | ojinaga
# Processing Record 26 of Set 14 | cagliliog
# Processing Record 27 of Set 14 | salihorsk
# Processing Record 28 of Set 14 | gogrial
# Processing Record 29 of Set 14 | cabinda
# Processing Record 30 of Set 14 | pilar
# Processing Record 31 of Set 14 | bardsir
# Processing Record 32 of Set 14 | necochea
# Processing Record 33 of Set 14 | tripoli
# Processing Record 34 of Set 14 | murgab
# Processing Record 35 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | mandalgovi
# Processing Record 37 of Set 14 | puerto quijarro
# Processing Record 38 of Set 14 | urumqi
# Processing Record 39 of Set 14 | bambanglipuro
# Processing Record 40 of Set 14 | kanker
# Processing Record 41 of Set 14 | birao
# Processing Record 42 of Set 14 | asifabad
# Processing Record 43 of Set 14 | sakakah
# Processing Record 44 of Set 14 | kilis
# Processing Record 45 of Set 14 | juneau
# Processing Record 46 of Set 14 | azuaga
# Processing Record 47 of Set 14 | licheng
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | labrea
# Processing Record 50 of Set 14 | kysyl-syr
# Processing Record 1 of Set 15 | zeya
# Processing Record 2 of Set 15 | mahibadhoo
# Processing Record 3 of Set 15 | albanel
# Processing Record 4 of Set 15 | sento se
# City not found. Skipping...
# Processing Record 5 of Set 15 | sfantu gheorghe
# Processing Record 6 of Set 15 | kitaibaraki
# Processing Record 7 of Set 15 | bauska
# Processing Record 8 of Set 15 | nome
# Processing Record 9 of Set 15 | saint-michel-des-saints
# Processing Record 10 of Set 15 | tsiroanomandidy
# Processing Record 11 of Set 15 | pryazha
# Processing Record 12 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 13 of Set 15 | pudozh
# Processing Record 14 of Set 15 | egvekinot
# Processing Record 15 of Set 15 | kadipur
# Processing Record 16 of Set 15 | skibbereen
# Processing Record 17 of Set 15 | houma
# Processing Record 18 of Set 15 | north platte
# Processing Record 19 of Set 15 | ewa beach
# Processing Record 20 of Set 15 | kuopio
# Processing Record 21 of Set 15 | japura
# Processing Record 22 of Set 15 | parrita
# Processing Record 23 of Set 15 | kiunga
# Processing Record 24 of Set 15 | abha
# Processing Record 25 of Set 15 | ulaangom
# Processing Record 26 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 15 | katherine
# Processing Record 28 of Set 15 | tigil
# Processing Record 29 of Set 15 | jatai
# Processing Record 30 of Set 15 | mukhen
# Processing Record 31 of Set 15 | wajir
# Processing Record 32 of Set 15 | kupang
# Processing Record 33 of Set 15 | morgan city
# Processing Record 34 of Set 15 | marana
# Processing Record 35 of Set 15 | makakilo city
# Processing Record 36 of Set 15 | uige
# Processing Record 37 of Set 15 | sao pedro do sul
# Processing Record 38 of Set 15 | chimoio
# Processing Record 39 of Set 15 | mongomo
# Processing Record 40 of Set 15 | abbeville
# Processing Record 41 of Set 15 | pathein
# Processing Record 42 of Set 15 | khorramshahr
# Processing Record 43 of Set 15 | clearlake
# Processing Record 44 of Set 15 | tak
# Processing Record 45 of Set 15 | pokaran
# Processing Record 46 of Set 15 | takaka
# Processing Record 47 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 15 | lubango
# Processing Record 49 of Set 15 | fort-shevchenko
# Processing Record 50 of Set 15 | palmas
# Processing Record 1 of Set 16 | strezhevoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.0707  172.7902     81.55        71          43
# 1     Jamestown      US  42.0970  -79.2353     18.99        52          98
# 2        Xiaoyi      CN  34.6178  109.7030     68.97        37           3
# 3     Busselton      AU -33.6500  115.3333     69.49        58          49
# 4       Paamiut      GL  61.9940  -49.6678     23.32        73          72
# 5    Morant Bay      JM  17.8815  -76.4093     78.42        82          21
# 6        Bethel      US  41.3712  -73.4140     27.95        66          35
# 7  Punta Arenas      CL -53.1500  -70.9167     42.12        75          54
# 8      Tevaitoa      PF -16.7833 -151.5000     82.22        73          28
# 9       Ushuaia      AR -54.8000  -68.3000     42.46        70          20
#
#    Wind Speed Current Description
# 0       10.80    scattered clouds
# 1        8.99     overcast clouds
# 2        7.05           clear sky
# 3       14.92    scattered clouds
# 4        7.00       broken clouds
# 5       14.52          few clouds
# 6        7.00    scattered clouds
# 7       10.87       broken clouds
# 8       13.40          light rain
# 9        4.61          few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Databae/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
